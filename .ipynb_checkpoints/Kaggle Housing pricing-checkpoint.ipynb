# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV

% matplotlib inline

# %%
trainhousingpd = pd.read_csv('train.csv',index_col='Id')
testhousingpd = pd.read_csv('test.csv', index_col='Id')

# %%
trainhousingpd.shape
# Out:
# (1460, 80)

# %%
# now for some eda
trainhousingpd.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 37 columns]

# %%
trainhousingpd.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 80, dtype: int64

# %%
trainhousingpd.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
testhousingpd.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
#                  ...
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         1
# TotRmsAbvGrd        0
# Functional          2
# Fireplaces          0
# FireplaceQu       730
# GarageType         76
# GarageYrBlt        78
# GarageFinish       78
# GarageCars          1
# GarageArea          1
# GarageQual         78
# GarageCond         78
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1456
# Fence            1169
# MiscFeature      1408
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# Length: 79, dtype: int64

# %%
trainhousingpd.corr()['SalePrice']
# Out:
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# YrSold          -0.028923
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
trainhousingpd[trainhousingpd['OverallQual'].isnull()]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %%
testhousingpd[testhousingpd['LotFrontage'].isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1467          20       RL          NaN     7980   Pave   NaN      IR1
# 1501         160       FV          NaN     2980   Pave   NaN      Reg
# 1502         160       FV          NaN     2403   Pave   NaN      IR1
# 1506          20       RL          NaN    10456   Pave   NaN      IR1
# 1508          50       RL          NaN    18837   Pave   NaN      IR1
# 1513          80       RL          NaN    10600   Pave  Pave      IR1
# 1520          20       RL          NaN     8050   Pave   NaN      IR1
# 1536          50       RM          NaN     8239   Pave   NaN      Reg
# 1543          75       RL          NaN     7793   Pave   NaN      IR1
# 1559          70  C (all)          NaN     6449   Pave   NaN      IR1
# 1564          90       RL          NaN     7424   Pave   NaN      IR1
# 1566          20       RL          NaN    20062   Pave   NaN      IR1
# 1568          60       RL          NaN    17082   Pave   NaN      IR1
# 1574          20       RL          NaN    11200   Pave   NaN      IR1
# 1580          60       RL          NaN     9337   Pave   NaN      IR1
# 1585         120       RM          NaN     4435   Pave   NaN      Reg
# 1593          30       RL          NaN     7890   Pave   NaN      Reg
# 1607          90       RL          NaN    12760   Pave   NaN      IR1
# 1613          20       RL          NaN    11875   Pave   NaN      Reg
# 1628          60       RL          NaN    11792   Pave   NaN      IR1
# 1635          60       RL          NaN     8803   Pave   NaN      IR1
# 1638          60       RL          NaN    13250   Pave   NaN      IR1
# 1640          60       RL          NaN    12388   Pave   NaN      IR1
# 1643          60       FV          NaN     7500   Pave   NaN      Reg
# 1644          60       FV          NaN     8470   Pave   NaN      Reg
# 1645          20       RL          NaN     9373   Pave   NaN      IR1
# 1648          20       RL          NaN     7830   Pave   NaN      IR1
# 1649          20       RL          NaN     8510   Pave   NaN      IR1
# 1660          20       RL          NaN    10710   Pave   NaN      Reg
# 1690          60       RL          NaN     8965   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2685          60       RL          NaN    12585   Pave   NaN      IR1
# 2701          60       RL          NaN     9019   Pave   NaN      IR1
# 2704          20       RL          NaN     9240   Pave   NaN      IR1
# 2705          20       RL          NaN     9308   Pave   NaN      IR1
# 2707          20       RL          NaN     8638   Pave   NaN      IR1
# 2708          20       RL          NaN    13052   Pave   NaN      IR1
# 2709          20       RL          NaN     8020   Pave   NaN      IR1
# 2710          20       RL          NaN     8789   Pave   NaN      IR1
# 2715         160       FV          NaN     2998   Pave   NaN      Reg
# 2716         160       FV          NaN     4447   Pave   NaN      IR1
# 2725          20       RL          NaN     9759   Pave   NaN      IR1
# 2728          20       RL          NaN    10368   Pave   NaN      IR1
# 2738          90       RL          NaN     8917   Pave   NaN      IR1
# 2739          80       RL          NaN    12700   Pave   NaN      IR1
# 2742          20       RL          NaN     9610   Pave   NaN      IR1
# 2765          60       RL          NaN    18275   Pave   NaN      IR1
# 2808          20       RL          NaN    11327   Pave   NaN      IR1
# 2811          20       RL          NaN     9535   Pave   NaN      IR1
# 2812          80       RL          NaN     7176   Pave   NaN      IR1
# 2813          90       RL          NaN     9662   Pave   NaN      IR1
# 2815          30       RL          NaN    17529   Pave   NaN      Reg
# 2816          20       RL          NaN    20355   Pave   NaN      Reg
# 2819         150       RL          NaN     1700   Pave   NaN      Reg
# 2840          20       RL          NaN     8685   Pave   NaN      IR1
# 2846          60       RL          NaN     9930   Pave   NaN      IR1
# 2848          20       RL          NaN    11088   Pave   NaN      Reg
# 2851          60       RL          NaN    21533   Pave   NaN      IR2
# 2901          20       RL          NaN    50102   Pave   NaN      IR1
# 2902          20       RL          NaN     8098   Pave   NaN      IR1
# 2909          90       RL          NaN    11836   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1467         Lvl    AllPub    Inside      ...                 0        0
# 1501         Lvl    AllPub    Corner      ...                 0        0
# 1502         Lvl    AllPub       FR2      ...                 0        0
# 1506         Lvl    AllPub    Inside      ...                 0        0
# 1508         Lvl    AllPub    Inside      ...                 0        0
# 1513         Lvl    AllPub    Inside      ...                 0        0
# 1520         Lvl    AllPub    Inside      ...                 0        0
# 1536         Lvl    AllPub    Inside      ...                 0        0
# 1543         Bnk    AllPub    Corner      ...                 0        0
# 1559         Lvl    AllPub    Inside      ...                 0        0
# 1564         Lvl    AllPub    Inside      ...                 0        0
# 1566         Low    AllPub    Inside      ...                 0        0
# 1568         Low    AllPub   CulDSac      ...                 0        0
# 1574         Lvl    AllPub   CulDSac      ...                 0        0
# 1580         Lvl    AllPub    Inside      ...                 0        0
# 1585         Lvl    AllPub    Inside      ...                 0        0
# 1593         Lvl    AllPub    Corner      ...               166        0
# 1607         Lvl    AllPub    Inside      ...                 0        0
# 1613         Lvl    AllPub    Inside      ...                 0        0
# 1628         Lvl    AllPub    Inside      ...                 0        0
# 1635         Lvl    AllPub    Inside      ...                 0        0
# 1638         Lvl    AllPub    Inside      ...                 0        0
# 1640         Lvl    AllPub    Inside      ...                 0        0
# 1643         Lvl    AllPub    Inside      ...                 0        0
# 1644         Lvl    AllPub    Corner      ...                 0        0
# 1645         Lvl    AllPub   CulDSac      ...               490        0
# 1648         Lvl    AllPub    Inside      ...                 0        0
# 1649         Lvl    AllPub    Inside      ...                 0        0
# 1660         Lvl    AllPub    Inside      ...                 0        0
# 1690         Lvl    AllPub    Inside      ...                 0        0
# ...          ...       ...       ...      ...               ...      ...
# 2685         Lvl    AllPub    Inside      ...                 0        0
# 2701         Lvl    AllPub    Inside      ...                 0        0
# 2704         Lvl    AllPub    Inside      ...                 0        0
# 2705         Lvl    AllPub   CulDSac      ...                 0        0
# 2707         Lvl    AllPub    Inside      ...                 0        0
# 2708         Lvl    AllPub   CulDSac      ...                 0        0
# 2709         Lvl    AllPub    Inside      ...                 0        0
# 2710         Lvl    AllPub    Inside      ...                 0        0
# 2715         Lvl    AllPub    Inside      ...                 0        0
# 2716         Lvl    AllPub       FR2      ...                 0        0
# 2725         Lvl    AllPub    Inside      ...                 0        0
# 2728         Lvl    AllPub   CulDSac      ...                 0        0
# 2738         Lvl    AllPub    Inside      ...                 0        0
# 2739         Lvl    AllPub    Inside      ...                 0        0
# 2742         Lvl    AllPub    Corner      ...                 0        0
# 2765         HLS    AllPub    Inside      ...                 0        0
# 2808         Lvl    AllPub    Inside      ...                 0        0
# 2811         Lvl    AllPub    Inside      ...                 0        0
# 2812         Lvl    AllPub   CulDSac      ...               180        0
# 2813         Lvl    AllPub    Inside      ...                 0        0
# 2815         Lvl    AllPub    Inside      ...                 0        0
# 2816         Low    AllPub    Inside      ...                 0        0
# 2819         HLS    AllPub    Inside      ...               200        0
# 2840         Lvl    AllPub   CulDSac      ...                 0        0
# 2846         Lvl    AllPub    Inside      ...                 0        0
# 2848         Lvl    AllPub    Corner      ...                 0        0
# 2851         Lvl    AllPub       FR2      ...                 0        0
# 2901         Low    AllPub    Inside      ...               138        0
# 2902         Lvl    AllPub    Inside      ...                 0        0
# 2909         Lvl    AllPub    Corner      ...                 0        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1467    NaN  GdPrv        Shed     500       3    2010        WD
# 1501    NaN    NaN         NaN       0       5    2010        WD
# 1502    NaN    NaN         NaN       0       6    2010        WD
# 1506    NaN    NaN         NaN       0       5    2010        WD
# 1508    NaN    NaN         NaN       0       4    2010        WD
# 1513    NaN    NaN         NaN       0       5    2010       COD
# 1520    NaN  GdPrv         NaN       0       5    2010        WD
# 1536    NaN    NaN         NaN       0       3    2010        WD
# 1543    NaN    NaN         NaN       0       5    2010        WD
# 1559    NaN    NaN         NaN       0       3    2010        WD
# 1564    NaN    NaN         NaN       0       5    2010        WD
# 1566    NaN    NaN         NaN       0       4    2010        WD
# 1568    NaN    NaN         NaN       0       5    2010        WD
# 1574    NaN    NaN         NaN       0       6    2010       COD
# 1580    NaN    NaN         NaN       0       4    2010        WD
# 1585    NaN    NaN         NaN       0       4    2010        WD
# 1593    NaN    NaN         NaN       0       3    2010        WD
# 1607    NaN    NaN         NaN       0       3    2010     ConLD
# 1613    NaN    NaN         NaN       0       6    2010        WD
# 1628    NaN    NaN         NaN       0       8    2009        WD
# 1635    NaN    NaN         NaN       0       7    2009        WD
# 1638    NaN    NaN         NaN       0       5    2009        WD
# 1640    NaN    NaN         NaN       0       8    2009        WD
# 1643    NaN    NaN         NaN       0       3    2009        WD
# 1644    NaN    NaN         NaN       0      10    2009        WD
# 1645    NaN    NaN         NaN       0       6    2009        WD
# 1648    NaN    NaN         NaN       0       3    2009       COD
# 1649    NaN    NaN         NaN       0       7    2009        WD
# 1660    NaN    NaN        Shed    1200       7    2009        WD
# 1690    NaN    NaN         NaN       0       6    2009        WD
# ...     ...    ...         ...     ...     ...     ...       ...
# 2685    NaN    NaN         NaN       0      10    2006        WD
# 2701    NaN    NaN         NaN       0       7    2006        WD
# 2704    NaN  MnPrv         NaN       0       3    2006        WD
# 2705    NaN  MnPrv         NaN       0       7    2006        WD
# 2707    NaN    NaN         NaN       0      10    2006        WD
# 2708    NaN  MnPrv         NaN       0       1    2006        WD
# 2709    NaN   GdWo         NaN       0       4    2006        WD
# 2710    NaN    NaN         NaN       0       6    2006        WD
# 2715    NaN    NaN         NaN       0       6    2006        WD
# 2716    NaN    NaN         NaN       0       7    2006        WD
# 2725    NaN    NaN         NaN       0       3    2006        WD
# 2728    NaN    NaN         NaN       0       4    2006        WD
# 2738    NaN    NaN         NaN       0      10    2006        WD
# 2739    NaN    NaN         NaN       0      11    2006        WD
# 2742    NaN    NaN         NaN       0      12    2006        WD
# 2765    NaN    NaN         NaN       0       9    2006        WD
# 2808    NaN    NaN         NaN       0       6    2006        WD
# 2811    NaN  MnPrv         NaN       0       7    2006        WD
# 2812    NaN  GdPrv         NaN       0       7    2006        WD
# 2813    NaN    NaN         NaN       0       8    2006        WD
# 2815    NaN    NaN         NaN       0       4    2006        WD
# 2816    NaN    NaN         NaN       0       6    2006        WD
# 2819    NaN    NaN         NaN       0       4    2006        WD
# 2840    NaN    NaN         NaN       0       5    2006        WD
# 2846    NaN    NaN         NaN       0       7    2006        WD
# 2848    NaN    NaN         NaN       0       6    2006        WD
# 2851    NaN    NaN         NaN       0       8    2006        WD
# 2901    NaN    NaN         NaN       0       3    2006        WD
# 2902    NaN    NaN         NaN       0      10    2006        WD
# 2909    NaN    NaN         NaN       0       3    2006        WD
#
#       SaleCondition
# Id
# 1467         Normal
# 1501         Normal
# 1502         Normal
# 1506         Normal
# 1508         Normal
# 1513         Family
# 1520         Normal
# 1536         Normal
# 1543         Normal
# 1559        Abnorml
# 1564         Normal
# 1566         Normal
# 1568         Normal
# 1574         Normal
# 1580         Normal
# 1585         Normal
# 1593         Normal
# 1607         Normal
# 1613         Normal
# 1628         Normal
# 1635         Normal
# 1638        Abnorml
# 1640         Normal
# 1643         Normal
# 1644         Normal
# 1645         Normal
# 1648         Normal
# 1649         Normal
# 1660         Normal
# 1690         Normal
# ...             ...
# 2685         Normal
# 2701         Normal
# 2704         Normal
# 2705         Normal
# 2707         Normal
# 2708         Normal
# 2709         Normal
# 2710         Normal
# 2715         Normal
# 2716         Normal
# 2725         Normal
# 2728         Normal
# 2738         Normal
# 2739         Normal
# 2742         Normal
# 2765         Normal
# 2808         Normal
# 2811         Normal
# 2812         Normal
# 2813         Normal
# 2815         Normal
# 2816         Normal
# 2819         Normal
# 2840         Normal
# 2846         Normal
# 2848         Normal
# 2851         Normal
# 2901         Alloca
# 2902         Normal
# 2909         Normal
#
# [227 rows x 79 columns]

# %%
# house 2577 doesn't have a garagearea. Lets fix that.
testhousingpd['GarageArea'][2577] = testhousingpd['GarageArea'].mean()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pd.get_dummies(trainhousingpd['MSSubClass'],prefix='MSSUB')
pd.get_dummies(trainhousingpd['MSZoning'],prefix='MSZone')
pd.get_dummies(trainhousingpd['Street'],prefix='MSZone')
pd.get_dummies(trainhousingpd['Alley'],prefix='Alley')
pd.get_dummies(trainhousingpd['Condition1'],prefix='Condition1')
pd.get_dummies(trainhousingpd['Condition2'],prefix='Condition2')
pd.get_dummies(trainhousingpd['BldgType'],prefix='BldgType')
pd.get_dummies(trainhousingpd['HouseStyle'],prefix='HouseStyle')
pd.get_dummies(trainhousingpd['SaleType'],prefix='SaleType')
pd.get_dummies(trainhousingpd['SaleCondition'],prefix='SaleCondition')
pd.get_dummies(trainhousingpd['CentralAir'],prefix='CentralAir')
pd.get_dummies(trainhousingpd['Neighborhood'],prefix='Neighborhood')
# Out:
#       Neighborhood_Blmngtn  Neighborhood_Blueste  Neighborhood_BrDale  \
# Id
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    0
# 4                        0                     0                    0
# 5                        0                     0                    0
# 6                        0                     0                    0
# 7                        0                     0                    0
# 8                        0                     0                    0
# 9                        0                     0                    0
# 10                       0                     0                    0
# 11                       0                     0                    0
# 12                       0                     0                    0
# 13                       0                     0                    0
# 14                       0                     0                    0
# 15                       0                     0                    0
# 16                       0                     0                    0
# 17                       0                     0                    0
# 18                       0                     0                    0
# 19                       0                     0                    0
# 20                       0                     0                    0
# 21                       0                     0                    0
# 22                       0                     0                    0
# 23                       0                     0                    0
# 24                       0                     0                    0
# 25                       0                     0                    0
# 26                       0                     0                    0
# 27                       0                     0                    0
# 28                       0                     0                    0
# 29                       0                     0                    0
# 30                       0                     0                    0
# ...                    ...                   ...                  ...
# 1431                     0                     0                    0
# 1432                     0                     0                    0
# 1433                     0                     0                    0
# 1434                     0                     0                    0
# 1435                     0                     0                    0
# 1436                     0                     0                    0
# 1437                     0                     0                    0
# 1438                     0                     0                    0
# 1439                     0                     0                    0
# 1440                     0                     0                    0
# 1441                     0                     0                    0
# 1442                     0                     0                    0
# 1443                     0                     0                    0
# 1444                     0                     0                    0
# 1445                     0                     0                    0
# 1446                     0                     0                    0
# 1447                     0                     0                    0
# 1448                     0                     0                    0
# 1449                     0                     0                    0
# 1450                     0                     0                    0
# 1451                     0                     0                    0
# 1452                     0                     0                    0
# 1453                     0                     0                    0
# 1454                     0                     0                    0
# 1455                     0                     0                    0
# 1456                     0                     0                    0
# 1457                     0                     0                    0
# 1458                     0                     0                    0
# 1459                     0                     0                    0
# 1460                     0                     0                    0
#
#       Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 1450                     0                    0                     0
# 1451                     0                    0                     0
# 1452                     0                    0                     0
# 1453                     0                    0                     0
# 1454                     0                    0                     0
# 1455                     0                    0                     0
# 1456                     0                    0                     0
# 1457                     0                    0                     0
# 1458                     0                    0                     0
# 1459                     0                    0                     0
# 1460                     0                    0                     0
#
# [1460 rows x 25 columns]

# %% [markdown]
# # time to feature engineer features that should be numeric
# ExterQual: (done)
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond (done)
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
# BsmtQual(done): Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond(done): Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement

# %%
# so, there's a coming grading system used for a lot of these, let's write a dictionary/function which allows for conversion

# %%
# so, there's a coming grading system used for a lot of these, let's write a dictionary/function which allows for conversion

def describetonum(stringdesc):
    if stringdesc=='Ex':
        return 5
    elif stringdesc=='Gd':
        return 4
    elif (stringdesc=='TA') | (stringdesc=='AllPub')| (stringdesc=='Reg'):
        return 3
    elif (stringdesc=='Fa') | (stringdesc=='NoSewr')| (stringdesc=='IR1'):
        return 2
    elif (stringdesc=='Po') | (stringdesc=='NoSeWa')| (stringdesc=='IR2'):
        return 1
    elif (stringdesc=='NA') | (stringdesc=='ELO')| (stringdesc=='IR3'):
        return 0
    else:
        return 0
def Funcnum(stringdesc):
    if stringdesc=='Typ':
        return 7
    elif stringdesc=='Min1':
        return 6
    elif stringdesc=='Min2':
        return 5
    elif stringdesc=='Mod':
        return 4
    elif stringdesc=='Maj1':
        return 3
    elif stringdesc=='Maj2':
        return 2
    elif stringdesc=='Sev':
        return 1
    elif stringdesc=='Sal':
        return 0
    else:
        return 0
trainhousingpd['ExterQual']= trainhousingpd['ExterQual'].apply(describetonum)    
trainhousingpd['LotShape']= trainhousingpd['LotShape'].apply(describetonum)
trainhousingpd['Utilities']= trainhousingpd['Utilities'].apply(describetonum)
trainhousingpd['ExterCond']= trainhousingpd['ExterCond'].apply(describetonum)
trainhousingpd['BsmtQual']= trainhousingpd['BsmtQual'].apply(describetonum)
trainhousingpd['BsmtCond']= trainhousingpd['BsmtCond'].apply(describetonum)
trainhousingpd['HeatingQC']= trainhousingpd['HeatingQC'].apply(describetonum)
trainhousingpd['Functional']= trainhousingpd['Functional'].apply(Funcnum)

# %%
trainhousingpd.head()
tempdlist = [ pd.get_dummies(trainhousingpd['CentralAir'],prefix='CentralAir'), pd.get_dummies(trainhousingpd['MSSubClass'],prefix='MSSUB')
,pd.get_dummies(trainhousingpd['MSZoning'],prefix='MSZone')
,pd.get_dummies(trainhousingpd['Street'],prefix='MSZone')
,pd.get_dummies(trainhousingpd['Alley'],prefix='Alley')
,pd.get_dummies(trainhousingpd['Condition1'],prefix='Condition1')
,pd.get_dummies(trainhousingpd['Condition2'],prefix='Condition2')
,pd.get_dummies(trainhousingpd['BldgType'],prefix='BldgType')
,pd.get_dummies(trainhousingpd['HouseStyle'],prefix='HouseStyle')
,pd.get_dummies(trainhousingpd['SaleType'],prefix='SaleType')
,pd.get_dummies(trainhousingpd['SaleCondition'],prefix='SaleCondition')
,pd.get_dummies(trainhousingpd['Neighborhood'],prefix='Neighborhood')
,trainhousingpd]
trainfeatureenged =pd.concat(tempdlist, axis=1)

# %%
trainfeatureenged.corr()['SalePrice'].sort_values()
# Out:
# MSZone_RM               -0.288065
# LotShape                -0.267759
# CentralAir_N            -0.251328
# SaleType_WD             -0.242598
# MSSUB_30                -0.238640
# Neighborhood_OldTown    -0.192189
# Neighborhood_NAmes      -0.188513
# Neighborhood_Edwards    -0.179949
# Neighborhood_IDOTRR     -0.164056
# HouseStyle_1.5Fin       -0.163466
# MSSUB_50                -0.156692
# SaleCondition_Normal    -0.153990
# Neighborhood_BrkSide    -0.143648
# Alley_Grvl              -0.139195
# KitchenAbvGr            -0.135907
# EnclosedPorch           -0.128578
# Neighborhood_Sawyer     -0.128394
# SaleCondition_Abnorml   -0.118069
# Condition1_Feedr        -0.117329
# BldgType_Duplex         -0.114655
# MSSUB_90                -0.114655
# MSSUB_160               -0.113042
# Neighborhood_MeadowV    -0.112544
# MSZone_C (all)          -0.111257
# Condition1_Artery       -0.106401
# Neighborhood_BrDale     -0.101303
# BldgType_Twnhs          -0.098730
# BldgType_2fmCon         -0.097348
# MSSUB_190               -0.093578
# HouseStyle_SFoyer       -0.093090
#                            ...
# CentralAir_Y             0.251328
# LotArea                  0.263843
# HalfBath                 0.284108
# OpenPorchSF              0.315856
# 2ndFlrSF                 0.319334
# WoodDeckSF               0.324413
# Neighborhood_NoRidge     0.330424
# LotFrontage              0.351799
# SaleCondition_Partial    0.352060
# SaleType_New             0.357509
# MSSUB_60                 0.377197
# BsmtFinSF1               0.386420
# Neighborhood_NridgHt     0.402149
# HeatingQC                0.427649
# Fireplaces               0.466929
# MasVnrArea               0.477493
# GarageYrBlt              0.486362
# YearRemodAdd             0.507101
# YearBuilt                0.522897
# TotRmsAbvGrd             0.533723
# FullBath                 0.560664
# BsmtQual                 0.585207
# 1stFlrSF                 0.605852
# TotalBsmtSF              0.613581
# GarageArea               0.623431
# GarageCars               0.640409
# ExterQual                0.682639
# GrLivArea                0.708624
# OverallQual              0.790982
# SalePrice                1.000000
# Name: SalePrice, Length: 141, dtype: float64

# %%
features = ['OverallQual', 
'GrLivArea','ExterQual','GarageCars','GarageArea', 'TotalBsmtSF', 
'1stFlrSF','BsmtQual', 'FullBath','TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'SaleType_New' , 
'SaleCondition_Partial', 'LotFrontage', 'LotArea','CentralAir_Y', 'LotShape', 'MSZone_RM', 
'SaleType_WD', 'MSSUB_30', 'MSSUB_50', 'YrSold', 'MoSold', 'Fireplaces', 'Utilities', 'Neighborhood_NridgHt', 'MSSUB_60',
  'Neighborhood_NoRidge' , 'Neighborhood_OldTown', 'Neighborhood_NAmes', 'Neighborhood_Edwards',   'Neighborhood_IDOTRR'     ]

# %%
# Out:
# numpy.ndarray

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-6ce27970db87> in <module>()
# ----> 1 checkforfeatures['SalePrice']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X= trainfeatureenged[features]
y=trainfeatureenged['SalePrice']
#note to self, lot frontage has nulls.

# %%
X.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'ExterQual', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'FullBath', 'TotRmsAbvGrd',
#        'YearBuilt', 'YearRemodAdd', 'SaleType_New', 'SaleCondition_Partial',
#        'LotFrontage', 'LotArea', 'CentralAir_Y', 'LotShape', 'MSZone_RM',
#        'SaleType_WD', 'MSSUB_30', 'MSSUB_50', 'YrSold', 'MoSold', 'Fireplaces',
#        'Utilities', 'Neighborhood_NridgHt', 'MSSUB_60', 'Neighborhood_NoRidge',
#        'Neighborhood_OldTown', 'Neighborhood_NAmes', 'Neighborhood_Edwards',
#        'Neighborhood_IDOTRR'],
#       dtype='object')

# %%
X.dropna(axis=1,inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'ExterQual', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'FullBath', 'TotRmsAbvGrd',
#        'YearBuilt', 'YearRemodAdd', 'SaleType_New', 'SaleCondition_Partial',
#        'LotArea', 'CentralAir_Y', 'LotShape', 'MSZone_RM', 'SaleType_WD',
#        'MSSUB_30', 'MSSUB_50', 'YrSold', 'MoSold', 'Fireplaces', 'Utilities',
#        'Neighborhood_NridgHt', 'MSSUB_60', 'Neighborhood_NoRidge',
#        'Neighborhood_OldTown', 'Neighborhood_NAmes', 'Neighborhood_Edwards',
#        'Neighborhood_IDOTRR'],
#       dtype='object')

# %%
pf = PolynomialFeatures(include_bias=False, degree=2)
X_poly = pf.fit_transform(X)

# %%
ss= StandardScaler()
ss.fit(X_poly)
X_poly_scaled = ss.transform(X_poly)

# %%
alphas = np.arange(0.0, 3.0, 0.1)
l1ratios = np.arange(0.0, 1.1, 0.1)

# %%
params = {'alpha': alphas, 'l1_ratio': l1ratios}
model = ElasticNet()
gs = GridSearchCV(model, param_grid=params, cv =4, scoring= 'r2')
gs.fit(X_poly_scaled, y)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:238: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:470: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   positive)

# %%
gs.best_score_
#this score is terrible, but let's try to finish the workflow
# Out:
# 0.85693384799129857

# %%
gs.best_estimator_
# Out:
# ElasticNet(alpha=0.30000000000000004, copy_X=True, fit_intercept=True,
#       l1_ratio=0.90000000000000002, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
workingmodel = ElasticNet(alpha=1.9000000000000001, copy_X=True, fit_intercept=True,
      l1_ratio=0.90000000000000002, max_iter=1000, normalize=False,
      positive=False, precompute=False, random_state=None,
      selection='cyclic', tol=0.0001, warm_start=False)

# %%
X_test= testhousingpd[features]
X_test.head()
# Out:
#       YrSold  LotArea
# Id
# 1461    2010    11622
# 1462    2010    14267
# 1463    2010    13830
# 1464    2010     9978
# 1465    2010     5005

# %%
model.fit(X_poly_scaled, y)
X_test= testhousingpd[features]
X_test_poly = pf.fit_transform(X_test)
ss.fit(X_poly)
X_test_scaled= ss.transform(X_test_poly)
pred= model.predict(X_test_scaled)

# %%
pred
# Out:
# array([ 182815.93903934,  190802.98435699,  189490.35844344, ...,
#         212184.48406672,  183727.54555593,  181243.31535961])

# %%
testhousingpd.index
# Out:
# Int64Index([1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470,
#             ...
#             2910, 2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919],
#            dtype='int64', name='Id', length=1459)

# %%
submission  = pd.DataFrame({'SalePrice':pred}, index = testhousingpd.index)

# %%
trainhousingpd.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %%
submission.to_csv('submission1.csv')
